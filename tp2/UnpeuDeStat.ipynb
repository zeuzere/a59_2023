# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in [ 10,  10000, 1000000]:
    x = np.random.uniform(size=i)
    plt.figure()
    plt.hist(x,bins=10)
    plt.figure()

# %%
for i in [ 10,  10000, 1000000]:
    x = np.random.normal(loc=0.0, scale
                         =1, size=i)
    plt.figure()
    plt.hist(x,bins=50)
    plt.figure()

# %%
m = np.mean(x)

# %%
m
# Out:
# -0.0010713785032297606

# %%
ec = np.std(x)

# %%
ec
# Out:
# 0.9986224911555699

# %%
for i in [ 1.0 , 2.0 ,5.0]:
    x = np.random.normal(scale=i,size=1000000)
    plt.figure()
    plt.xlim(-20,20)
    plt.hist(x, bins=50)
    plt.figure()

# %%
ec = np.std(x)
print(ec)
# Out:
# 4.999148648374745

# %%
m=np.mean(x)

# %%
np.sqrt(np.sum(np.power(x-m,2))/1000000)
# Out:
# 4.999148648374745

# %% [markdown]
# Population entre la moyenne et l'ec<br>
# 1 ec 68%
# 3 ec = 98%

# %%
np.sum(np.abs(x-m)<ec)/1000000
# Out:
# 0.683068

# %%
np.sum(np.abs(x-m)<3*ec)/1000000
# Out:
# 0.997231

# %% [markdown]
# ## Exemple
#
# This is a simple dataset to start with. It contains only the height (inches) and weights (pounds) of 25,000 different humans of 18 years of age. This dataset can be used to build a model that can predict the heights or weights of a human.

# %%
import pandas as pd

# %%
df=pd.read_csv("hauteurs_poids.csv")

# %%
df.columns
# Out:
# Index(['Index', 'hauteur', 'poid'], dtype='object')

# %%
df.hauteur = df.hauteur * 2.54

# %%
df.hauteur.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
np.mean(df.hauteur)
# Out:
# 172.702508535872

# %%
np.std(df.hauteur)
# Out:
# 4.830167472614602

# %% [markdown]
# # Donc 99% de la population a une hauteur comprise entre 172 -/+ (4.8 *3)

# %%
df.poid.plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>
